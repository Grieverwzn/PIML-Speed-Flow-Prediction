# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from geopy.distance import geodesic

# %%
sensor = pd.read_csv("data/sensor_infomation.csv")
sensor
# Out:
#          ID  Fwy Dir  District  County     City State_PM   Abs_PM   Latitude  \
# 0    715933    5   N         7      37  14974.0    10.33  126.963  33.981839
# 1    715938    5   N         7      37  14974.0    12.18  128.813  34.002541
# 2    715944    5   N         7      37  14974.0    13.35  129.983  34.013676
# 3    715947    5   S         7      37  14974.0    13.67  130.240  34.015325
# 4    716010    5   S         7      37  69088.0    R49.5  165.847  34.368149
# ..      ...  ...  ..       ...     ...      ...      ...      ...        ...
# 145  774672  110   N         7      37  44000.0     21.7   21.630  34.041951
# 146  774728   10   W         7      37  58072.0     47.2   45.700  34.081720
# 147  775155  405   N         7      37      NaN     31.3   55.072  34.052632
# 148  775610  110   S         7      37  44000.0     23.8   23.730  34.063457
# 149  775734    5   N         7      37  44000.0    24.36  140.993  34.120938
#
# ...

# %%
def calculate_distance(sen1, sen2):
    point1 = (sen1['Latitude'], sen1['Longitude'])
    point2 = (sen2['Latitude'], sen2['Longitude'])
    return geodesic(point1, point2).kilometers

# %%
# Proximity matrix construction
num_sensor = sensor.shape[0]
proximity_matrix = np.zeros((num_sensor, num_sensor), dtype=np.int32)

for i in range(len(sensor)):
    
    sensor_i = sensor.iloc[i,:] 
    sensor_cal = sensor[(sensor['Fwy']==sensor_i['Fwy'])&(sensor['Dir']==sensor_i['Dir'])&(sensor['ID']!=sensor_i['ID'])]
    
    if len(sensor_cal)<3:
        proximity_matrix[i,sensor_cal.index]=1
    else:
        for j in sensor_cal.index:
            sensor_cal.loc[j,'distance'] = geodesic((sensor_cal.loc[j,'Latitude'],sensor_cal.loc[j,'Longitude']), 
                                                    (sensor_i['Latitude'],sensor_i['Longitude'])).kilometers
        sensor_cal = sensor_cal.sort_values(by='distance', ascending=True)
        proximity_matrix[i,sensor_cal.index[:3]]=1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
pd.DataFrame(proximity_matrix).to_csv('data/adj_matrix/proximity_matrix.csv',index=False)

# %%
# Correlation graph of traffic flow
data_flow = pd.read_csv("data/training_flow.csv").iloc[:,1:]

Correlation_matrix_flow = data_flow.corr()
Correlation_matrix_flow = Correlation_matrix_flow.abs()

pd.DataFrame(Correlation_matrix_flow).to_csv('data/adj_matrix/Correlation_matrix_flow.csv',index=False)
print(Correlation_matrix_flow.shape)
Correlation_matrix_flow
# Out:
# (150, 150)
#           715933    715938    715944    715947    716010    716081    716087  \
# 715933  1.000000  0.958736  0.917525  0.733231  0.790792  0.622534  0.674101
# 715938  0.958736  1.000000  0.956441  0.736045  0.795386  0.669901  0.718077
# 715944  0.917525  0.956441  1.000000  0.724312  0.757859  0.671026  0.710504
# 715947  0.733231  0.736045  0.724312  1.000000  0.536164  0.517571  0.561386
# 716010  0.790792  0.795386  0.757859  0.536164  1.000000  0.611440  0.653861
# ...          ...       ...       ...       ...       ...       ...       ...
# 774672  0.820519  0.815432  0.790842  0.862631  0.623968  0.479736  0.530034
# 774728  0.805143  0.807069  0.771174  0.508206  0.755150  0.525749  0.570948
# 775155  0.747506  0.761260  0.737578  0.765896  0.623156  0.673195  0.719028
# 775610  0.838934  0.845906  0.815660  0.753831  0.716146  0.654307  0.700781
# 775734  0.894217  0.898961  0.848108  0.689095  0.811433  0.720913  0.764644
#
# ...

# %%
# Correlation graph of speed
data_speed = pd.read_csv("data/training_speed.csv").iloc[:,1:]

Correlation_matrix_speed = data_speed.corr()
Correlation_matrix_speed = Correlation_matrix_speed.abs()

pd.DataFrame(Correlation_matrix_speed).to_csv('data/adj_matrix/Correlation_matrix_speed.csv',index=False)
print(Correlation_matrix_speed.shape)
Correlation_matrix_speed
# Out:
# (150, 150)
#           715933    715938    715944    715947    716010    716081    716087  \
# 715933  1.000000  0.715241  0.609567  0.102733  0.242765  0.054413  0.009036
# 715938  0.715241  1.000000  0.717723  0.261556  0.282323  0.083433  0.168553
# 715944  0.609567  0.717723  1.000000  0.051043  0.223804  0.051131  0.006711
# 715947  0.102733  0.261556  0.051043  1.000000  0.259126  0.824131  0.840831
# 716010  0.242765  0.282323  0.223804  0.259126  1.000000  0.217970  0.212168
# ...          ...       ...       ...       ...       ...       ...       ...
# 774672  0.394257  0.528790  0.376859  0.705152  0.321162  0.613138  0.678345
# 774728  0.420163  0.421076  0.413135  0.049618  0.156911  0.036911  0.003586
# 775155  0.160632  0.284332  0.171605  0.772931  0.325203  0.743041  0.740518
# 775610  0.411399  0.504469  0.422983  0.430773  0.270083  0.365423  0.371041
# 775734  0.219933  0.326410  0.216547  0.545286  0.257606  0.529012  0.497953
#
# ...

# %%
from sklearn.neighbors import NearestNeighbors

# %%
# K-nearest neighbor graph-flow
X = data_flow.values
X = np.transpose(X)
X = np.nan_to_num(X, nan=0, posinf=0, neginf=0)

# Establish a knn model
knn = NearestNeighbors(n_neighbors=4)
knn.fit(X)
distances, indices = knn.kneighbors(X) 

knn_matrix_flow = np.zeros((len(X), len(X)))

for i in range(len(X)): 
    for j in indices[i]:
        knn_matrix_flow[i, j] = 1
        knn_matrix_flow[j, i] = 1
    
    knn_matrix_flow[i, i] = 0 

pd.DataFrame(knn_matrix_flow).to_csv('data/adj_matrix/knn_matrix_flow.csv',index=False)

# %%
# K-nearest neighbor graph-speed
X = data_speed.values
X = np.transpose(X)
X = np.nan_to_num(X, nan=0, posinf=0, neginf=0)

# Establish a knn model
knn = NearestNeighbors(n_neighbors=4)
knn.fit(X)
distances, indices = knn.kneighbors(X)

knn_matrix_speed = np.zeros((len(X), len(X)))

for i in range(len(X)): 
    for j in indices[i]:
        knn_matrix_speed[i, j] = 1
        knn_matrix_speed[j, i] = 1
    
    knn_matrix_speed[i, i] = 0 

pd.DataFrame(knn_matrix_speed).to_csv('data/adj_matrix/knn_matrix_speed.csv',index=False)
